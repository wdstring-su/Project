# %%
import pandas as pd
import numpy as np
import statsmodels.api as sm
import statsmodels.formula.api as smf
from sklearn import linear_model as lm
import collections
# %matplotlib inline

import warnings
warnings.filterwarnings(action="ignore", module="scipy", message="^internal gelsd")

data1 = pd.read_csv('round_regression_data.csv', index_col=["Player ID"])
df1 = pd.DataFrame(data1)
df1.head()

y = df1['Round'].values
x1 = df1['Games'].values
x2 = df1['Total Rebounds'].values
x3 = df1['Free Throw Percentage'].values
x4 = df1['Points Per Game'].values
x5 = df1['Total Rebounds Per Game'].values

y = df1['Round'].values
X = df1[['Games', 'Total Rebounds', 'Free Throw Percentage', 'Points Per Game', 'Total Rebounds Per Game']].values
X = sm.add_constant(X)
model = sm.OLS(y, X).fit()
model.summary()

y = df1['Round'].values
X = df1[['Games', 'Total Rebounds', 'Free Throw Percentage', 'Points Per Game', 'Total Rebounds Per Game']].values
model = lm.LinearRegression()
reg = model.fit(X,y)

b0 = reg.intercept_
b1 = reg.coef_[0]
b2 = reg.coef_[1]
b3 = reg.coef_[2]
b4 = reg.coef_[3]
b5 = reg.coef_[4]

x1 = float(input('Enter Number of Games: '))
x2 = float(input('Enter Total Rebounds Per Season: '))
x3 = float(input('Enter Free Throw Percentage as a Decimal: '))
x4 = float(input('Enter Points Per Game Average: '))
x5 = float(input('Enter Total Rebounds Per Game Average: '))

y = (b1*x1) + (b2*x2) + (b3*x3) + (b4*x4) + (b5*x5) + b0
y = round(y)

print("")

if y==1:
    print('Player will likely be drafted in the first round.')
elif y==2:
    print('Player will most likely be drafted in the second round.')
else:
    print('Unlikely player will be drafted into the NBA.')
    
data2 = pd.read_csv('overall_pick_regression_data.csv', index_col=["Player ID"])
df2 = pd.DataFrame(data2)
df2.head()

y = df2['Overall Pick'].values
X = df2[['Games', 'Minutes Played', 'Free Throw Percentage', 'Minutes Per Game', 'Points Per Game', 'Total Rebounds Per Game']].values
X = sm.add_constant(X)
model = sm.OLS(y, X).fit()
model.summary()

y = df2['Overall Pick'].values
X = df2[['Games', 'Minutes Played', 'Free Throw Percentage', 'Minutes Per Game', 'Points Per Game', 'Total Rebounds Per Game']].values
model = lm.LinearRegression()
reg = model.fit(X,y)

b0 = reg.intercept_
b1 = reg.coef_[0]
b2 = reg.coef_[1]
b3 = reg.coef_[2]
b4 = reg.coef_[3]
b5 = reg.coef_[4]
b6 = reg.coef_[5]

print("")

x1 = float(input('Enter Number of Games: '))
x2 = float(input('Enter Total Minutes Played: '))
x3 = float(input('Enter Free Throw Percentage as a Decimal: '))
x4 = float(input('Enter Minutes Per Game: '))
x5 = float(input('Enter Points Per Game Average: '))
x6 = float(input('Enter Total Rebounds Per Game Average: '))

y = (b1*x1) + (b2*x2) + (b3*x3) + (b4*x4) + (b5*x5) + (b6*x6) + b0
y = round(y)

print("")

if 1 <= y <= 60:
    print('Player is predicted to be overall draft pick number %.0f' % (y))
else:
    print('Unlikely player will be drafted by the NBA')
# Out:
# /Users/Hope/miniconda3/lib/python3.6/site-packages/statsmodels/compat/pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools
# Enter Number of Games: 66
# Enter Total Rebounds Per Season: 473
# Enter Free Throw Percentage as a Decimal: .752
# Enter Points Per Game Average: 10.4
# Enter Total Rebounds Per Game Average: 7.2
#
# Player will likely be drafted in the first round.
#
# Enter Number of Games: 66
# Enter Total Minutes Played: 1543
# Enter Free Throw Percentage as a Decimal: .752
# Enter Minutes Per Game: 23.4
# Enter Point Per Game Average: 10.4
# Enter Total Rebounds Per Game Average: 7.2
#
# Player is predicted to be overall draft pick number 18
